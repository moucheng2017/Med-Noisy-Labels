# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import errno
import torch
import timeit
import imageio
import numpy as np
import torch.nn as nn

# %%
from adamW import AdamW
from torch.utils import data
import matplotlib.pyplot as plt
from tensorboardX import SummaryWriter
from Loss import noisy_label_loss
from Utilis import segmentation_scores, CustomDataset_punet, calculate_cm
from Utilis import evaluate_noisy_label_4, evaluate_noisy_label_5, evaluate_noisy_label_6
# our proposed model:
from Models import UNet_CMs, UNet_GlobalCMs
from PIL import Image

# %%
# ========================= #
# Hyper-parameters setting
# ========================= #

# hyper-parameters for model:
input_dim = 3 # dimension of input
width = 24 # width of the network
depth = 3 # depth of the network, downsampling times is (depth-1)
class_no = 2 # class number, 2 for binary

# hyper-parameters for training:
train_batchsize = 5 # batch size
alpha = 0.001 # weight of the trace regularisation of learnt confusion matrices
num_epochs = 10 # total epochs
learning_rate = 1e-1 # learning rate

# %%
# ======================================= #
# Prepare a few data examples from MNIST 
# ======================================= #

# Change path for your own datasets here:
#data_path = './MNIST_examples'
#dataset_tag = 'mnist'
#label_mode = 'multi'

### INSERT CODE ###
data_path = './oocytes_gent/'
dataset_tag = 'oocytes_gent'
label_mode = 'multi'
### ----------- ###

# full path to train/validate/test:
test_path = data_path + '/test' 
train_path = data_path + '/train'
validate_path = data_path + '/validate'

# prepare data sets using our customdataset
train_dataset = CustomDataset_punet(dataset_location=train_path, dataset_tag=dataset_tag, noisylabel=label_mode, augmentation=True)
validate_dataset = CustomDataset_punet(dataset_location=validate_path, dataset_tag=dataset_tag, noisylabel=label_mode, augmentation=False)
test_dataset = CustomDataset_punet(dataset_location=test_path, dataset_tag=dataset_tag, noisylabel=label_mode, augmentation=False)

# putting dataset into data loaders
trainloader = data.DataLoader(train_dataset, batch_size=train_batchsize, shuffle=True, num_workers=2, drop_last=True)
validateloader = data.DataLoader(validate_dataset, batch_size=1, shuffle=False, drop_last=False)
testloader = data.DataLoader(test_dataset, batch_size=1, shuffle=False, drop_last=False)

# demonstrate the training samples:
Image_index_to_demonstrate = 3
images, labels_AR, labels_HS, labels_SG, imagename = validate_dataset[Image_index_to_demonstrate]
images = np.mean(images, axis=0)
i_height, i_width = images.shape
# print('The dimension of image, channel:' + str(np.shape(images)[0]) + ', height:' + str(np.shape(images)[1]) + ', width:' + str(np.shape(images)[2]))
# print('The dimension of label, channel:' + str(np.shape(labels_over)[0]) + ', height:' + str(np.shape(labels_over)[1]) + ', width:' + str(np.shape(labels_over)[2]))

# plot input image:
# the input image is original mnist images with gaussian noises
# plt.imshow(np.mean(images, axis=0), cmap='gray')
# plt.title('Input image')
# plt.show()

# plot the labels:
fig = plt.figure(figsize=(9, 13))
columns = 4 # images, labels_AR, labels_HS, labels_SG
rows = 1
ax = []
labels = []
labels_names = []
labels.append(images)
labels.append(labels_AR)
labels.append(labels_HS)
labels.append(labels_SG)
#labels.append(labels_good)
labels_names.append('Input')
labels_names.append('AR label')
labels_names.append('HS label')
labels_names.append('SG label')
#labels_names.append('Good label')

for i in range(columns*rows):
    if i != 0:
        label_ = labels[i][0, :, :]
    else:
        label_ = labels[i]
    ax.append(fig.add_subplot(rows, columns, i+1))
    ax[-1].set_title(labels_names[i]) 
    plt.imshow(label_, cmap='gray')
plt.show()

# %%
# ===== #
# Model
# ===== #

# call model:
# model = UNet_CMs(in_ch=input_dim, width=width, depth=depth, class_no=class_no, norm='in', low_rank=False)
model = UNet_GlobalCMs(in_ch=input_dim, width=width, depth=depth, class_no=class_no, 
                       input_height= i_height, input_width=i_width, annotators=3)
# model name for saving:
model_name = 'UNet_Confusion_Matrices_' + '_width' + str(width) + \
           '_depth' + str(depth) + '_train_batch_' + str(train_batchsize) + \
           '_alpha_' + str(alpha) + '_e' + str(num_epochs) + \
           '_lr' + str(learning_rate) 
print('cuda' if torch.cuda.is_available() else 'cpu')
# setting up device:
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
# Out:
# cuda
# UNet_GlobalCMs(
#   (decoders): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(48, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): InstanceNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (2): PReLU(num_parameters=1)
#       (3): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): InstanceNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (5): PReLU(num_parameters=1)
#     )
#     (1): Sequential(
#       (0): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): InstanceNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (2): PReLU(num_parameters=1)
#       (3): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): InstanceNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (5): PReLU(num_parameters=1)
#     )
#     (2): Sequential(
#       (0): Conv2d(96, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): InstanceNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (2): PReLU(num_parameters=1)
#       (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): InstanceNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (5): PReLU(num_parameters=1)
#     )
#   )
#   (encoders): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(3, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): InstanceNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (2): PReLU(num_parameters=1)
#       (3): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): InstanceNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (5): PReLU(num_parameters=1)
#     )
#     (1): Sequential(
#       (0): Conv2d(24, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): InstanceNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (2): PReLU(num_parameters=1)
#       (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): InstanceNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (5): PReLU(num_parameters=1)
#     )
#     (2): Sequential(
#       (0): Conv2d(48, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): InstanceNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (2): PReLU(num_parameters=1)
#       (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): InstanceNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (5): PReLU(num_parameters=1)
#     )
#   )
#   (upsample): Upsample(scale_factor=2.0, mode=bilinear)
#   (conv_last): Conv2d(24, 2, kernel_size=(1, 1), stride=(1, 1))
#   (decoders_noisy_layers): ModuleList(
#     (0): gcm_layers(
#       (relu): Softplus(beta=1, threshold=20)
#     )
#     (1): gcm_layers(
#       (relu): Softplus(beta=1, threshold=20)
#     )
#     (2): gcm_layers(
#       (relu): Softplus(beta=1, threshold=20)
#     )
#   )
# )

# %%
# =================================================== #
# Prepare folders to save trained models and results 
# =================================================== #

# save location:
saved_information_path = './Results_Oocytes_Gent'
try:
    os.mkdir(saved_information_path)
except OSError as exc:
    if exc.errno != errno.EEXIST:
        raise
    pass

saved_information_path = saved_information_path + '/' + model_name
try:
    os.mkdir(saved_information_path)
except OSError as exc:
    if exc.errno != errno.EEXIST:
        raise
    pass

saved_model_path = saved_information_path + '/trained_models'
try:
    os.mkdir(saved_model_path)
except OSError as exc:
    if exc.errno != errno.EEXIST:
        raise
    pass

save_path_visual_result = saved_information_path + '/visual_results'
try:
    os.mkdir(save_path_visual_result)
except OSError as exc:
    if exc.errno != errno.EEXIST:
        raise
    pass

# tensorboardX file saved location:
writer = SummaryWriter('./Results_Oocytes_Gent/Log_' + model_name)

# %%
plt.imshow(images)

# %%
# =================================================== #
# Training
# =================================================== #

# We use adamW optimiser for more accurate L2 regularisation
optimizer = AdamW(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-8, weight_decay=1e-5)

for epoch in range(num_epochs):
    model.train()
    
    running_loss = 0
    running_loss_ce = 0
    running_loss_trace = 0
    running_iou = 0
    
    for j, (images, labels_AR, labels_HS, labels_SG, imagename) in enumerate(trainloader):
        
        b, c, h, w = images.size()

        # zero gradients before each iteration
        optimizer.zero_grad()
        
        # cast numpy data into tensor float
        images = images.to(device=device, dtype=torch.float32)
        labels_AR = labels_AR.to(device=device, dtype=torch.float32)
        labels_HS = labels_HS.to(device=device, dtype=torch.float32)
        labels_SG = labels_SG.to(device=device, dtype=torch.float32)
        #labels_good = labels_good.to(device=device, dtype=torch.float32)
        
        labels_all = []
        labels_all.append(labels_AR)
        labels_all.append(labels_HS)
        labels_all.append(labels_SG)
        #labels_all.append(labels_good)
        
        # model has two outputs: 
        # first one is the probability map for true ground truth 
        # second one is a list collection of probability maps for different noisy ground truths

        outputs_logits, outputs_logits_noisy = model(images)
        print(outputs_logits.shape)
        
        # calculate loss:
        # loss: total loss
        # loss_ce: main cross entropy loss
        # loss_trace: regularisation loss
        loss, loss_ce, loss_trace = noisy_label_loss(outputs_logits, outputs_logits_noisy, labels_all, alpha)

        # calculate the gradients:
        loss.backward()
        # update weights in model:
        optimizer.step()
        
        _, train_output = torch.max(outputs_logits, dim=1)
        #train_iou = segmentation_scores(labels_good.cpu().detach().numpy(), train_output.cpu().detach().numpy(), class_no)
        train_iou = segmentation_scores(labels_AR.cpu().detach().numpy(), train_output.cpu().detach().numpy(), class_no)
        running_loss += loss
        running_loss_ce += loss_ce
        running_loss_trace += loss_trace
        running_iou += train_iou

        if (j + 1) == 1:
            # check the validation accuray at the begning of each epoch:
            v_dice, v_ged = evaluate_noisy_label_4(data=validateloader,
                                                   model1=model,
                                                   class_no=class_no)
            
            print(
                'Step [{}/{}], '
                'Val dice: {:.4f},'
                'Val GED: {:.4f},'
                'loss main: {:.4f},'
                'loss regualrisation: {:.4f},'.format(epoch + 1, num_epochs,
                                                            v_dice,
                                                            v_ged,
                                                            running_loss_ce / (j + 1),
                                                            running_loss_trace / (j + 1)))
        
            writer.add_scalars('scalars', {'loss': running_loss / (j + 1),
                                           'train iou': running_iou / (j + 1),
                                           'val iou': v_dice,
                                           'train main loss': running_loss_ce / (j + 1),
                                           'train regularisation loss': running_loss_trace / (j + 1)}, epoch + 1)

# save model:
save_model_name_full = saved_model_path + '/' + model_name + '_Final.pt'
torch.save(model, save_model_name_full)
print('\n')
print('Training ended')
# Out:
# torch.Size([5, 2, 192, 256])
# Step [1/100], Val dice: 0.9684,Val GED: 1.9672,loss main: 0.9569,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [2/100], Val dice: 0.9680,Val GED: 1.9672,loss main: 0.9672,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [3/100], Val dice: 0.9678,Val GED: 1.9672,loss main: 0.9666,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [4/100], Val dice: 0.9682,Val GED: 1.9672,loss main: 0.9571,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [5/100], Val dice: 0.9682,Val GED: 1.9673,loss main: 0.9640,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [6/100], Val dice: 0.9683,Val GED: 1.9673,loss main: 0.9763,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [7/100], Val dice: 0.9680,Val GED: 1.9673,loss main: 0.9597,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [8/100], Val dice: 0.9682,Val GED: 1.9673,loss main: 0.9573,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [9/100], Val dice: 0.9680,Val GED: 1.9673,loss main: 0.9626,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [10/100], Val dice: 0.9686,Val GED: 1.9673,loss main: 0.9570,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [11/100], Val dice: 0.9678,Val GED: 1.9674,loss main: 0.9651,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [12/100], Val dice: 0.9678,Val GED: 1.9673,loss main: 0.9588,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [13/100], Val dice: 0.9687,Val GED: 1.9673,loss main: 0.9532,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [14/100], Val dice: 0.9680,Val GED: 1.9674,loss main: 0.9603,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [15/100], Val dice: 0.9681,Val GED: 1.9673,loss main: 0.9776,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [16/100], Val dice: 0.9681,Val GED: 1.9673,loss main: 0.9619,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [17/100], Val dice: 0.9680,Val GED: 1.9674,loss main: 0.9546,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [18/100], Val dice: 0.9678,Val GED: 1.9674,loss main: 0.9665,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [19/100], Val dice: 0.9672,Val GED: 1.9674,loss main: 0.9870,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [20/100], Val dice: 0.9679,Val GED: 1.9674,loss main: 0.9588,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [21/100], Val dice: 0.9679,Val GED: 1.9674,loss main: 0.9546,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [22/100], Val dice: 0.9683,Val GED: 1.9674,loss main: 0.9775,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [23/100], Val dice: 0.9687,Val GED: 1.9674,loss main: 0.9738,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [24/100], Val dice: 0.9684,Val GED: 1.9674,loss main: 0.9755,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [25/100], Val dice: 0.9687,Val GED: 1.9674,loss main: 0.9529,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [26/100], Val dice: 0.9689,Val GED: 1.9674,loss main: 0.9550,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [27/100], Val dice: 0.9683,Val GED: 1.9674,loss main: 0.9654,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [28/100], Val dice: 0.9683,Val GED: 1.9674,loss main: 0.9649,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [29/100], Val dice: 0.9673,Val GED: 1.9675,loss main: 0.9574,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [30/100], Val dice: 0.9678,Val GED: 1.9674,loss main: 0.9536,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [31/100], Val dice: 0.9678,Val GED: 1.9674,loss main: 0.9576,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [32/100], Val dice: 0.9668,Val GED: 1.9675,loss main: 0.9660,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [33/100], Val dice: 0.9685,Val GED: 1.9675,loss main: 0.9587,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [34/100], Val dice: 0.9670,Val GED: 1.9675,loss main: 0.9611,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [35/100], Val dice: 0.9670,Val GED: 1.9675,loss main: 0.9533,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [36/100], Val dice: 0.9665,Val GED: 1.9675,loss main: 0.9804,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [37/100], Val dice: 0.9671,Val GED: 1.9675,loss main: 0.9597,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [38/100], Val dice: 0.9665,Val GED: 1.9674,loss main: 0.9578,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [39/100], Val dice: 0.9665,Val GED: 1.9674,loss main: 0.9795,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [40/100], Val dice: 0.9675,Val GED: 1.9674,loss main: 0.9669,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [41/100], Val dice: 0.9678,Val GED: 1.9674,loss main: 0.9729,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [42/100], Val dice: 0.9667,Val GED: 1.9674,loss main: 0.9557,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [43/100], Val dice: 0.9675,Val GED: 1.9674,loss main: 0.9603,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [44/100], Val dice: 0.9670,Val GED: 1.9675,loss main: 0.9581,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [45/100], Val dice: 0.9670,Val GED: 1.9675,loss main: 0.9570,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [46/100], Val dice: 0.9676,Val GED: 1.9674,loss main: 0.9604,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [47/100], Val dice: 0.9673,Val GED: 1.9674,loss main: 0.9523,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [48/100], Val dice: 0.9669,Val GED: 1.9675,loss main: 0.9535,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [49/100], Val dice: 0.9672,Val GED: 1.9674,loss main: 0.9560,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [50/100], Val dice: 0.9672,Val GED: 1.9675,loss main: 0.9627,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [51/100], Val dice: 0.9671,Val GED: 1.9675,loss main: 0.9589,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [52/100], Val dice: 0.9674,Val GED: 1.9674,loss main: 0.9774,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [53/100], Val dice: 0.9674,Val GED: 1.9674,loss main: 0.9532,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [54/100], Val dice: 0.9668,Val GED: 1.9675,loss main: 0.9598,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [55/100], Val dice: 0.9674,Val GED: 1.9675,loss main: 0.9600,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [56/100], Val dice: 0.9675,Val GED: 1.9675,loss main: 0.9687,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [57/100], Val dice: 0.9676,Val GED: 1.9675,loss main: 0.9803,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [58/100], Val dice: 0.9661,Val GED: 1.9675,loss main: 0.9596,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [59/100], Val dice: 0.9668,Val GED: 1.9675,loss main: 0.9617,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [60/100], Val dice: 0.9662,Val GED: 1.9675,loss main: 0.9660,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [61/100], Val dice: 0.9672,Val GED: 1.9674,loss main: 0.9548,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [62/100], Val dice: 0.9668,Val GED: 1.9675,loss main: 0.9546,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [63/100], Val dice: 0.9664,Val GED: 1.9675,loss main: 0.9546,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [64/100], Val dice: 0.9666,Val GED: 1.9675,loss main: 0.9593,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [65/100], Val dice: 0.9664,Val GED: 1.9675,loss main: 0.9571,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [66/100], Val dice: 0.9672,Val GED: 1.9675,loss main: 0.9627,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [67/100], Val dice: 0.9665,Val GED: 1.9675,loss main: 0.9746,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [68/100], Val dice: 0.9658,Val GED: 1.9675,loss main: 0.9562,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [69/100], Val dice: 0.9664,Val GED: 1.9675,loss main: 0.9726,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [70/100], Val dice: 0.9667,Val GED: 1.9675,loss main: 0.9553,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [71/100], Val dice: 0.9666,Val GED: 1.9675,loss main: 0.9587,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [72/100], Val dice: 0.9649,Val GED: 1.9676,loss main: 0.9586,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [73/100], Val dice: 0.9665,Val GED: 1.9675,loss main: 0.9528,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [74/100], Val dice: 0.9659,Val GED: 1.9676,loss main: 0.9578,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [75/100], Val dice: 0.9659,Val GED: 1.9675,loss main: 0.9716,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [76/100], Val dice: 0.9652,Val GED: 1.9675,loss main: 0.9627,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [77/100], Val dice: 0.9659,Val GED: 1.9675,loss main: 0.9567,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [78/100], Val dice: 0.9655,Val GED: 1.9675,loss main: 0.9558,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [79/100], Val dice: 0.9652,Val GED: 1.9676,loss main: 0.9741,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [80/100], Val dice: 0.9662,Val GED: 1.9675,loss main: 0.9614,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [81/100], Val dice: 0.9658,Val GED: 1.9675,loss main: 0.9593,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [82/100], Val dice: 0.9657,Val GED: 1.9675,loss main: 0.9845,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [83/100], Val dice: 0.9662,Val GED: 1.9675,loss main: 0.9742,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [84/100], Val dice: 0.9650,Val GED: 1.9676,loss main: 0.9654,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [85/100], Val dice: 0.9667,Val GED: 1.9675,loss main: 0.9533,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [86/100], Val dice: 0.9650,Val GED: 1.9676,loss main: 0.9555,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [87/100], Val dice: 0.9659,Val GED: 1.9675,loss main: 0.9674,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [88/100], Val dice: 0.9660,Val GED: 1.9675,loss main: 0.9522,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [89/100], Val dice: 0.9652,Val GED: 1.9676,loss main: 0.9532,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [90/100], Val dice: 0.9653,Val GED: 1.9676,loss main: 0.9504,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [91/100], Val dice: 0.9652,Val GED: 1.9676,loss main: 0.9637,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [92/100], Val dice: 0.9648,Val GED: 1.9676,loss main: 0.9568,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [93/100], Val dice: 0.9653,Val GED: 1.9675,loss main: 0.9683,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [94/100], Val dice: 0.9647,Val GED: 1.9676,loss main: 0.9597,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [95/100], Val dice: 0.9662,Val GED: 1.9675,loss main: 0.9664,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [96/100], Val dice: 0.9648,Val GED: 1.9676,loss main: 0.9663,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [97/100], Val dice: 0.9662,Val GED: 1.9676,loss main: 0.9703,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [98/100], Val dice: 0.9652,Val GED: 1.9676,loss main: 0.9547,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [99/100], Val dice: 0.9653,Val GED: 1.9676,loss main: 0.9741,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# Step [100/100], Val dice: 0.9656,Val GED: 1.9676,loss main: 0.9536,loss regualrisation: 0.0060,
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
# torch.Size([5, 2, 192, 256])
#
#
# Training ended

# %%
learning_rate = 1e-3 # learning rate
num_epochs = 100 # total epochs

# %%
# =================================================== #
# Testing
# =================================================== #
model.eval()
for i, (v_images, labels_over, labels_under, labels_wrong, labels_good, imagename) in enumerate(testloader):
        v_images = v_images.to(device=device, dtype=torch.float32)
        v_outputs_logits_original, v_outputs_logits_noisy = model(v_images)
        b, c, h, w = v_outputs_logits_original.size()
        # plot the final segmentation map
        v_outputs_logits_original = nn.Softmax(dim=1)(v_outputs_logits_original)
        _, v_outputs_logits = torch.max(v_outputs_logits_original, dim=1)

        save_name = save_path_visual_result + '/test_' + str(i) + '_seg.png'
        save_name_label = save_path_visual_result + '/test_' + str(i) + '_label.png'
        save_name_slice = save_path_visual_result + '/test_' + str(i) + '_img.png'

        plt.imsave(save_name_slice, v_images[:, 1, :, :].reshape(h, w).cpu().detach().numpy(), cmap='gray')
        plt.imsave(save_name, v_outputs_logits.reshape(h, w).cpu().detach().numpy(), cmap='gray')
        plt.imsave(save_name_label, labels_good.reshape(h, w).cpu().detach().numpy(), cmap='gray')
        
        # plot the noisy segmentation maps:
        v_outputs_logits_original = v_outputs_logits_original.reshape(b, c, h*w)
        v_outputs_logits_original = v_outputs_logits_original.permute(0, 2, 1).contiguous()
        v_outputs_logits_original = v_outputs_logits_original.view(b * h * w, c).view(b*h*w, c, 1)
        for j, cm in enumerate(v_outputs_logits_noisy):
            cm = cm.view(b, c**2, h*w).permute(0, 2, 1).contiguous().view(b*h*w, c*c).view(b*h*w, c, c)
            cm = cm / cm.sum(1, keepdim=True)
            v_noisy_output_original = torch.bmm(cm, v_outputs_logits_original).view(b*h*w, c)
            v_noisy_output_original = v_noisy_output_original.view(b, h*w, c).permute(0, 2, 1).contiguous().view(b, c, h, w)
            _, v_noisy_output = torch.max(v_noisy_output_original, dim=1)
            save_name = save_path_visual_result + '/test_' + str(i) + '_noisy_' + str(j) + '_seg.png'
            plt.imsave(save_name, v_noisy_output.reshape(h, w).cpu().detach().numpy(), cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 5
#       1 # =================================================== #
#       2 # Testing
#       3 # =================================================== #
#       4 model.eval()
# ----> 5 for i, (v_images, labels_over, labels_under, labels_wrong, labels_good, imagename) in enumerate(testloader):
#       6         v_images = v_images.to(device=device, dtype=torch.float32)
#       7         v_outputs_logits_original, v_outputs_logits_noisy = model(v_images)
#
# ValueError: not enough values to unpack (expected 6, got 5)

# %%
# =================================================== #
# Predictions Plot
# =================================================== #
test_data_index = 15

over_seg = save_path_visual_result + '/test_' + str(test_data_index) + '_noisy_' + str(0) + '_seg.png'
under_seg = save_path_visual_result + '/test_' + str(test_data_index) + '_noisy_' + str(1) + '_seg.png'
wrong_seg = save_path_visual_result + '/test_' + str(test_data_index) + '_noisy_' + str(2) + '_seg.png'
good_seg = save_path_visual_result + '/test_' + str(test_data_index) + '_noisy_' + str(3) + '_seg.png'

seg = save_path_visual_result + '/test_' + str(test_data_index) + '_seg.png'
label = save_path_visual_result + '/test_' + str(test_data_index) + '_label.png'
img = save_path_visual_result + '/test_' + str(test_data_index) + '_img.png'

# plot image, ground truth and final segmentation
fig = plt.figure(figsize=(6.7, 13))
columns = 3
rows = 1

ax = []
imgs = []
imgs_names = []

imgs.append(img)
imgs.append(label)
imgs.append(seg)

imgs_names.append('Test img')
imgs_names.append('GroundTruth')
imgs_names.append('Pred of true seg')

for i in range(columns*rows):
    img_ = imgs[i]
    ax.append(fig.add_subplot(rows, columns, i+1))
    ax[-1].set_title(imgs_names[i]) 
    img_ = Image.open(img_)
    img_ = np.array(img_, dtype='uint8')
    plt.imshow(img_, cmap='gray')
plt.show()

# plot the segmentation for noisy labels:
fig = plt.figure(figsize=(9, 13))
columns = 4
rows = 1

ax = []
noisy_segs = []
noisy_segs_names = []

noisy_segs.append(over_seg)
noisy_segs.append(under_seg)
noisy_segs.append(wrong_seg)
noisy_segs.append(good_seg)

noisy_segs_names.append('Pred of over')
noisy_segs_names.append('Pred of under')
noisy_segs_names.append('Pred of wrong')
noisy_segs_names.append('Pred of good')

for i in range(columns*rows):
    noisy_seg_ = noisy_segs[i]
    ax.append(fig.add_subplot(rows, columns, i+1))
    ax[-1].set_title(noisy_segs_names[i]) 
    noisy_seg_ = Image.open(noisy_seg_)
    noisy_seg_ = np.array(noisy_seg_, dtype='uint8' )
    plt.imshow(noisy_seg_, cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[51], line 36
#      34 ax.append(fig.add_subplot(rows, columns, i+1))
#      35 ax[-1].set_title(imgs_names[i])
# ---> 36 img_ = Image.open(img_)
#      37 img_ = np.array(img_, dtype='uint8')
#      38 plt.imshow(img_, cmap='gray')
#
# File ~/prj/Learn_Noisy_Labels_Medical_Images/.venv/lib/python3.10/site-packages/PIL/Image.py:3227, in open(fp, mode, formats)
#    3224     filename = fp
#    3226 if filename:
# -> 3227     fp = builtins.open(filename, "rb")
#    3228     exclusive_fp = True
#    3230 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: './Results_Oocytes_Gent/UNet_Confusion_Matrices__width24_depth3_train_batch_5_alpha_0.01_e10_lr0.1/visual_results/test_15_img.png'
